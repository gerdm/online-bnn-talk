# %% [markdown]
# # Demo with rebayes mini

# %%
import jax
import optax
import numpy as np
import jax.numpy as jnp
import flax.linen as nn
import matplotlib.pyplot as plt
from cycler import cycler
from matplotlib.animation import FuncAnimation

# %%
from rebayes_mini import callbacks
from rebayes_mini.methods import kalman_filter as kf
from rebayes_mini.methods import replay_sgd as rsgd

# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = "retina"

# %%
plt.style.use('dark_background')

acolors = [
    "#D9117F",
    "#0DD9D9",
    "#F2A30F",
    "#F26E22",
]

colors = list(v["color"] for v in plt.rcParams["axes.prop_cycle"])

# %%
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False

# %%
def f(x):
    return x - 10 * jnp.cos(x) * jnp.sin(x) + x ** 3


def sample_observations(key, f, n_obs, xmin, xmax, x_noise=0.1, y_noise=3.0):
    key_x, key_y, key_shuffle = jax.random.split(key, 3)
    x_noise = jax.random.normal(key_x, (n_obs,)) * x_noise
    y_noise = jax.random.normal(key_y, (n_obs,)) * y_noise
    x = jnp.linspace(xmin, xmax, n_obs) + x_noise
    y = f(x) + y_noise
    
    X = jnp.c_[x, y]
    shuffled_ixs = jax.random.permutation(key_shuffle, jnp.arange(n_obs))
    x, y = jnp.array(X[shuffled_ixs, :].T)
    
    return x, y

# %%
key = jax.random.PRNGKey(314)
key_train, key_sample_obs, key_eval = jax.random.split(key, 3)

n_obs = 200
xmin, xmax = -3, 3
sigma_y = 3.0
x, y = sample_observations(key_sample_obs, f, n_obs, xmin, xmax, x_noise=0, y_noise=sigma_y)
xtest = jnp.linspace(x.min(), x.max(), n_obs)

# %%
plt.scatter(x, y, edgecolors=colors[0], color="none")
plt.grid(alpha=0.3)

# %%
class MLP(nn.Module):
    @nn.compact
    def __call__(self, x):
        x = nn.Dense(6)(x)
        x = nn.elu(x)
        x = nn.Dense(6)(x)
        x = nn.elu(x)
        x = nn.Dense(6)(x)
        x = nn.elu(x)
        x = nn.Dense(1)(x)
        return x

# %%
model = MLP()
params_init = model.init(key_train, x[:, None])

def lossfn(params, counter, x, y, applyfn):
    yhat = applyfn(params, x)
    return jnp.sum(counter * (y - yhat) ** 2) / counter.sum()

# %%
tx = optax.adam(1e-2)

# %%
n_inner = 1
agent_sgd = rsgd.FifoSGD(
    model.apply, lossfn, tx, buffer_size=10, dim_features=1, dim_output=1,
    n_inner=n_inner
)
bel_init = agent_sgd.init_bel(params_init)
bel_sgd, hist_bel_sgd = agent_sgd.scan(bel_init, y, x[:, None], callbacks.get_updated_mean)
yhat_sgd = model.apply(bel_sgd.params, xtest[:, None]).ravel()

# %%
agent_ekf = kf.GaussianFilter(
    model.apply, dynamics_covariance=1e-4, variance=1.0
    
)

bel_init = agent_ekf.init_bel(params_init, cov=0.5)

bel_ekf, hist_bel_ekf = agent_ekf.scan(bel_init, y, x[:, None], callbacks.get_updated_bel)

yhat_ekf = agent_ekf.link_fn(bel_ekf.mean, xtest[:, None]).ravel()

# %%
plt.scatter(x, y, edgecolors=colors[0], c="none", alpha=0.8)
plt.plot(xtest, yhat_ekf, c=acolors[2], linewidth=4, label="EKF")
plt.plot(xtest, yhat_sgd, c=acolors[0], linewidth=4, label=f"oSGD({n_inner})")
plt.legend()
ymin, ymax = plt.ylim()
plt.grid(alpha=0.2)

# %% [markdown]
# ### Animate

# %%
fig, ax = plt.subplots()


def animate(t):
    ax.cla()
    params_t = jax.tree_map(lambda x: x[t], hist_bel_ekf)
    yhat_ekf = agent_ekf.link_fn(params_t, xtest[:, None]).ravel()
    
    params_t = jax.tree_map(lambda x: x[t], hist_bel_sgd)
    yhat_sgd = agent_sgd.apply_fn(params_t, xtest[:, None]).ravel()


    plt.scatter(x[:t], y[:t], edgecolors=colors[0], c="none", alpha=0.8)
    plt.scatter(x[t], y[t], c="white")
    plt.plot(xtest, yhat_sgd, c=acolors[2], linewidth=4, label=f"oSGD({n_inner})")
    plt.plot(xtest, yhat_ekf, c=acolors[0], linewidth=4, label=f"EKF")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.ylim(y.min(), y.max())

animation = FuncAnimation(fig, animate, frames=n_obs)
animation.save(f"ekf-osgd{n_inner}.gif", fps=15)
# animation.save(f"ekf.gif", fps=15)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %% [markdown]
# ## Animate: mean and covariance samples

# %%
hist_bel_ekf = jax.tree_map(np.array, hist_bel_ekf)
xcpu, ycpu = np.array(x), np.array(y)
xtest_cpu = np.array(xtest)

# %%
# %%time
n_params_samples = 50

fig, ax = plt.subplots()
def animate(t):
    ax.cla()
    bel_t = jax.tree_map(lambda x: x[t], hist_bel_ekf)

    # params_samples = jax.random.multivariate_normal(key_eval, bel_t.mean, bel_t.cov, shape=(n_params_samples,), method="svd")
    params_samples = np.random.default_rng(seed=314).multivariate_normal(bel_t.mean, bel_t.cov, size=n_params_samples, method="svd")

    yhat_ekf_samples = jax.vmap(agent_ekf.link_fn, in_axes=(0, None))(params_samples, xtest_cpu[:, None]).squeeze()
    yhat_ekf_mean = yhat_ekf_samples.mean(axis=0)
    plt.plot(xtest_cpu, yhat_ekf_samples.T, c="tab:gray", alpha=0.5, linewidth=1)
    plt.plot(xtest_cpu, yhat_ekf_mean, c=acolors[0], linewidth=4, label="EKF")

    plt.scatter(xcpu[:t], ycpu[:t], edgecolors=colors[0], c="none", alpha=0.8)
    plt.scatter(xcpu[t], ycpu[t], c="white", zorder=3, s=50)

    plt.grid(alpha=0.2)
    plt.legend(loc="upper right")
    plt.ylim(ymin, ymax)
    
animation = FuncAnimation(fig, animate, frames=n_obs)
animation.save(f"ekf.gif", fps=10)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# <timed exec>:9: RuntimeWarning: covariance is not symmetric positive-semidefinite.
# CPU times: user 22min 10s, sys: 24min 8s, total: 46min 19s
# Wall time: 2min 7s
